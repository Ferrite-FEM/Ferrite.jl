# %% [markdown]
# ## Solve heat conduction on a square with a uniform area specific heat source

# %%
using JuAFEM
using UnicodePlots
using Plots
pgfplots()
# Out:
# Plots.PGFPlotsBackend()

# %%
const dim = 1

function_order = 3
geometry_interpolation = Lagrange{dim, RefCube, 1}
function_interpolation = Lagrange{dim, RefCube, function_order}()
qr = QuadratureRule{dim, RefCube}(function_order + 1)
# Out:
# JuAFEM.QuadratureRule{1,JuAFEM.RefCube,Float64}([0.347855,0.652145,0.652145,0.347855],Tensors.Tensor{1,1,Float64,1}[[-0.861136],[-0.339981],[0.339981],[0.861136]])

# %%
grid = generate_grid(geometry_interpolation, (50,))
# Out:
# JuAFEM.Grid{1,2,Float64,2,JuAFEM.Lagrange{1,JuAFEM.RefCube,1}} with 50 Line cells and 51 nodes

# %%
cellvalues = CellScalarValues(qr, function_interpolation, geometry_interpolation());

# %%
dh = DofHandler(grid)
push!(dh, :T, function_interpolation, 1) # Add a temperature field
close!(dh)
# Out:
# Adding node dofs: [1] for global vertex: 1 local vertex: 1
# Adding node dofs: [2] for global vertex: 2 local vertex: 2
# Reusing node dofs [2] for global vertex: 2 local vertex: 1
# Adding node dofs: [3] for global vertex: 3 local vertex: 2
# Reusing node dofs [3] for global vertex: 3 local vertex: 1
# Adding node dofs: [4] for global vertex: 4 local vertex: 2
# Reusing node dofs [4] for global vertex: 4 local vertex: 1
# Adding node dofs: [5] for global vertex: 5 local vertex: 2
# Reusing node dofs [5] for global vertex: 5 local vertex: 1
# Adding node dofs: [6] for global vertex: 6 local vertex: 2
# Reusing node dofs [6] for global vertex: 6 local vertex: 1
# Adding node dofs: [7] for global vertex: 7 local vertex: 2
# Reusing node dofs [7] for global vertex: 7 local vertex: 1
# Adding node dofs: [8] for global vertex: 8 local vertex: 2
# Reusing node dofs [8] for global vertex: 8 local vertex: 1
# Adding node dofs: [9] for global vertex: 9 local vertex: 2
# Reusing node dofs [9] for global vertex: 9 local vertex: 1
# Adding node dofs: [10] for global vertex: 10 local vertex: 2
# Reusing node dofs [10] for global vertex: 10 local vertex: 1
# Adding node dofs: [11] for global vertex: 11 local vertex: 2
# Reusing node dofs [11] for global vertex: 11 local vertex: 1
# Adding node dofs: [12] for global vertex: 12 local vertex: 2
# Reusing node dofs [12] for global vertex: 12 local vertex: 1
# Adding node dofs: [13] for global vertex: 13 local vertex: 2
# Reusing node dofs [13] for global vertex: 13 local vertex: 1
# Adding node dofs: [14] for global vertex: 14 local vertex: 2
# Reusing node dofs [14] for global vertex: 14 local vertex: 1
# Adding node dofs: [15] for global vertex: 15 local vertex: 2
# Reusing node dofs [15] for global vertex: 15 local vertex: 1
# Adding node dofs: [16] for global vertex: 16 local vertex: 2
# Reusing node dofs [16] for global vertex: 16 local vertex: 1
# Adding node dofs: [17] for global vertex: 17 local vertex: 2
# Reusing node dofs [17] for global vertex: 17 local vertex: 1
# Adding node dofs: [18] for global vertex: 18 local vertex: 2
# Reusing node dofs [18] for global vertex: 18 local vertex: 1
# Adding node dofs: [19] for global vertex: 19 local vertex: 2
# Reusing node dofs [19] for global vertex: 19 local vertex: 1
# Adding node dofs: [20] for global vertex: 20 local vertex: 2
# Reusing node dofs [20] for global vertex: 20 local vertex: 1
# Adding node dofs: [21] for global vertex: 21 local vertex: 2
# Reusing node dofs [21] for global vertex: 21 local vertex: 1
# Adding node dofs: [22] for global vertex: 22 local vertex: 2
# Reusing node dofs [22] for global vertex: 22 local vertex: 1
# Adding node dofs: [23] for global vertex: 23 local vertex: 2
# Reusing node dofs [23] for global vertex: 23 local vertex: 1
# Adding node dofs: [24] for global vertex: 24 local vertex: 2
# Reusing node dofs [24] for global vertex: 24 local vertex: 1
# Adding node dofs: [25] for global vertex: 25 local vertex: 2
# Reusing node dofs [25] for global vertex: 25 local vertex: 1
# Adding node dofs: [26] for global vertex: 26 local vertex: 2
# Reusing node dofs [26] for global vertex: 26 local vertex: 1
# Adding node dofs: [27] for global vertex: 27 local vertex: 2
# Reusing node dofs [27] for global vertex: 27 local vertex: 1
# Adding node dofs: [28] for global vertex: 28 local vertex: 2
# Reusing node dofs [28] for global vertex: 28 local vertex: 1
# Adding node dofs: [29] for global vertex: 29 local vertex: 2
# Reusing node dofs [29] for global vertex: 29 local vertex: 1
# Adding node dofs: [30] for global vertex: 30 local vertex: 2
# Reusing node dofs [30] for global vertex: 30 local vertex: 1
# Adding node dofs: [31] for global vertex: 31 local vertex: 2
# Reusing node dofs [31] for global vertex: 31 local vertex: 1
# Adding node dofs: [32] for global vertex: 32 local vertex: 2
# Reusing node dofs [32] for global vertex: 32 local vertex: 1
# Adding node dofs: [33] for global vertex: 33 local vertex: 2
# Reusing node dofs [33] for global vertex: 33 local vertex: 1
# Adding node dofs: [34] for global vertex: 34 local vertex: 2
# Reusing node dofs [34] for global vertex: 34 local vertex: 1
# Adding node dofs: [35] for global vertex: 35 local vertex: 2
# Reusing node dofs [35] for global vertex: 35 local vertex: 1
# Adding node dofs: [36] for global vertex: 36 local vertex: 2
# Reusing node dofs [36] for global vertex: 36 local vertex: 1
# Adding node dofs: [37] for global vertex: 37 local vertex: 2
# Reusing node dofs [37] for global vertex: 37 local vertex: 1
# Adding node dofs: [38] for global vertex: 38 local vertex: 2
# Reusing node dofs [38] for global vertex: 38 local vertex: 1
# Adding node dofs: [39] for global vertex: 39 local vertex: 2
# Reusing node dofs [39] for global vertex: 39 local vertex: 1
# Adding node dofs: [40] for global vertex: 40 local vertex: 2
# Reusing node dofs [40] for global vertex: 40 local vertex: 1
# Adding node dofs: [41] for global vertex: 41 local vertex: 2
# Reusing node dofs [41] for global vertex: 41 local vertex: 1
# Adding node dofs: [42] for global vertex: 42 local vertex: 2
# Reusing node dofs [42] for global vertex: 42 local vertex: 1
# Adding node dofs: [43] for global vertex: 43 local vertex: 2
# Reusing node dofs [43] for global vertex: 43 local vertex: 1
# Adding node dofs: [44] for global vertex: 44 local vertex: 2
# Reusing node dofs [44] for global vertex: 44 local vertex: 1
# Adding node dofs: [45] for global vertex: 45 local vertex: 2
# Reusing node dofs [45] for global vertex: 45 local vertex: 1
# Adding node dofs: [46] for global vertex: 46 local vertex: 2
# Reusing node dofs [46] for global vertex: 46 local vertex: 1
# Adding node dofs: [47] for global vertex: 47 local vertex: 2
# Reusing node dofs [47] for global vertex: 47 local vertex: 1
# Adding node dofs: [48] for global vertex: 48 local vertex: 2
# Reusing node dofs [48] for global vertex: 48 local vertex: 1
# Adding node dofs: [49] for global vertex: 49 local vertex: 2
# Reusing node dofs [49] for global vertex: 49 local vertex: 1
# Adding node dofs: [50] for global vertex: 50 local vertex: 2
# Reusing node dofs [50] for global vertex: 50 local vertex: 1
# Adding node dofs: [51] for global vertex: 51 local vertex: 2
# Adding cell dofs: [52,53], for global cell 1
# Adding cell dofs: [54,55], for global cell 2
# Adding cell dofs: [56,57], for global cell 3
# Adding cell dofs: [58,59], for global cell 4
# Adding cell dofs: [60,61], for global cell 5
# Adding cell dofs: [62,63], for global cell 6
# Adding cell dofs: [64,65], for global cell 7
# Adding cell dofs: [66,67], for global cell 8
# Adding cell dofs: [68,69], for global cell 9
# Adding cell dofs: [70,71], for global cell 10
# Adding cell dofs: [72,73], for global cell 11
# Adding cell dofs: [74,75], for global cell 12
# Adding cell dofs: [76,77], for global cell 13
# Adding cell dofs: [78,79], for global cell 14
# Adding cell dofs: [80,81], for global cell 15
# Adding cell dofs: [82,83], for global cell 16
# Adding cell dofs: [84,85], for global cell 17
# Adding cell dofs: [86,87], for global cell 18
# Adding cell dofs: [88,89], for global cell 19
# Adding cell dofs: [90,91], for global cell 20
# Adding cell dofs: [92,93], for global cell 21
# Adding cell dofs: [94,95], for global cell 22
# Adding cell dofs: [96,97], for global cell 23
# Adding cell dofs: [98,99], for global cell 24
# Adding cell dofs: [100,101], for global cell 25
# Adding cell dofs: [102,103], for global cell 26
# Adding cell dofs: [104,105], for global cell 27
# Adding cell dofs: [106,107], for global cell 28
# Adding cell dofs: [108,109], for global cell 29
# Adding cell dofs: [110,111], for global cell 30
# Adding cell dofs: [112,113], for global cell 31
# Adding cell dofs: [114,115], for global cell 32
# Adding cell dofs: [116,117], for global cell 33
# Adding cell dofs: [118,119], for global cell 34
# Adding cell dofs: [120,121], for global cell 35
# Adding cell dofs: [122,123], for global cell 36
# Adding cell dofs: [124,125], for global cell 37
# Adding cell dofs: [126,127], for global cell 38
# Adding cell dofs: [128,129], for global cell 39
# Adding cell dofs: [130,131], for global cell 40
# Adding cell dofs: [132,133], for global cell 41
# Adding cell dofs: [134,135], for global cell 42
# Adding cell dofs: [136,137], for global cell 43
# Adding cell dofs: [138,139], for global cell 44
# Adding cell dofs: [140,141], for global cell 45
# Adding cell dofs: [142,143], for global cell 46
# Adding cell dofs: [144,145], for global cell 47
# Adding cell dofs: [146,147], for global cell 48
# Adding cell dofs: [148,149], for global cell 49
# Adding cell dofs: [150,151], for global cell 50
# For cell 1, adding vertex dof 1 to row 1
# For cell 1, adding vertex dof 2 to row 2
# For cell 1, adding cell dof 52 to number 3
# For cell 1, adding cell dof 53 to number 4
# For cell 2, adding vertex dof 2 to row 1
# For cell 2, adding vertex dof 3 to row 2
# For cell 2, adding cell dof 54 to number 3
# For cell 2, adding cell dof 55 to number 4
# For cell 3, adding vertex dof 3 to row 1
# For cell 3, adding vertex dof 4 to row 2
# For cell 3, adding cell dof 56 to number 3
# For cell 3, adding cell dof 57 to number 4
# For cell 4, adding vertex dof 4 to row 1
# For cell 4, adding vertex dof 5 to row 2
# For cell 4, adding cell dof 58 to number 3
# For cell 4, adding cell dof 59 to number 4
# For cell 5, adding vertex dof 5 to row 1
# For cell 5, adding vertex dof 6 to row 2
# For cell 5, adding cell dof 60 to number 3
# For cell 5, adding cell dof 61 to number 4
# For cell 6, adding vertex dof 6 to row 1
# For cell 6, adding vertex dof 7 to row 2
# For cell 6, adding cell dof 62 to number 3
# For cell 6, adding cell dof 63 to number 4
# For cell 7, adding vertex dof 7 to row 1
# For cell 7, adding vertex dof 8 to row 2
# For cell 7, adding cell dof 64 to number 3
# For cell 7, adding cell dof 65 to number 4
# For cell 8, adding vertex dof 8 to row 1
# For cell 8, adding vertex dof 9 to row 2
# For cell 8, adding cell dof 66 to number 3
# For cell 8, adding cell dof 67 to number 4
# For cell 9, adding vertex dof 9 to row 1
# For cell 9, adding vertex dof 10 to row 2
# For cell 9, adding cell dof 68 to number 3
# For cell 9, adding cell dof 69 to number 4
# For cell 10, adding vertex dof 10 to row 1
# For cell 10, adding vertex dof 11 to row 2
# For cell 10, adding cell dof 70 to number 3
# For cell 10, adding cell dof 71 to number 4
# For cell 11, adding vertex dof 11 to row 1
# For cell 11, adding vertex dof 12 to row 2
# For cell 11, adding cell dof 72 to number 3
# For cell 11, adding cell dof 73 to number 4
# For cell 12, adding vertex dof 12 to row 1
# For cell 12, adding vertex dof 13 to row 2
# For cell 12, adding cell dof 74 to number 3
# For cell 12, adding cell dof 75 to number 4
# For cell 13, adding vertex dof 13 to row 1
# For cell 13, adding vertex dof 14 to row 2
# For cell 13, adding cell dof 76 to number 3
# For cell 13, adding cell dof 77 to number 4
# For cell 14, adding vertex dof 14 to row 1
# For cell 14, adding vertex dof 15 to row 2
# For cell 14, adding cell dof 78 to number 3
# For cell 14, adding cell dof 79 to number 4
# For cell 15, adding vertex dof 15 to row 1
# For cell 15, adding vertex dof 16 to row 2
# For cell 15, adding cell dof 80 to number 3
# For cell 15, adding cell dof 81 to number 4
# For cell 16, adding vertex dof 16 to row 1
# For cell 16, adding vertex dof 17 to row 2
# For cell 16, adding cell dof 82 to number 3
# For cell 16, adding cell dof 83 to number 4
# For cell 17, adding vertex dof 17 to row 1
# For cell 17, adding vertex dof 18 to row 2
# For cell 17, adding cell dof 84 to number 3
# For cell 17, adding cell dof 85 to number 4
# For cell 18, adding vertex dof 18 to row 1
# For cell 18, adding vertex dof 19 to row 2
# For cell 18, adding cell dof 86 to number 3
# For cell 18, adding cell dof 87 to number 4
# For cell 19, adding vertex dof 19 to row 1
# For cell 19, adding vertex dof 20 to row 2
# For cell 19, adding cell dof 88 to number 3
# For cell 19, adding cell dof 89 to number 4
# For cell 20, adding vertex dof 20 to row 1
# For cell 20, adding vertex dof 21 to row 2
# For cell 20, adding cell dof 90 to number 3
# For cell 20, adding cell dof 91 to number 4
# For cell 21, adding vertex dof 21 to row 1
# For cell 21, adding vertex dof 22 to row 2
# For cell 21, adding cell dof 92 to number 3
# For cell 21, adding cell dof 93 to number 4
# For cell 22, adding vertex dof 22 to row 1
# For cell 22, adding vertex dof 23 to row 2
# For cell 22, adding cell dof 94 to number 3
# For cell 22, adding cell dof 95 to number 4
# For cell 23, adding vertex dof 23 to row 1
# For cell 23, adding vertex dof 24 to row 2
# For cell 23, adding cell dof 96 to number 3
# For cell 23, adding cell dof 97 to number 4
# For cell 24, adding vertex dof 24 to row 1
# For cell 24, adding vertex dof 25 to row 2
# For cell 24, adding cell dof 98 to number 3
# For cell 24, adding cell dof 99 to number 4
# For cell 25, adding vertex dof 25 to row 1
# For cell 25, adding vertex dof 26 to row 2
# For cell 25, adding cell dof 100 to number 3
# For cell 25, adding cell dof 101 to number 4
# For cell 26, adding vertex dof 26 to row 1
# For cell 26, adding vertex dof 27 to row 2
# For cell 26, adding cell dof 102 to number 3
# For cell 26, adding cell dof 103 to number 4
# For cell 27, adding vertex dof 27 to row 1
# For cell 27, adding vertex dof 28 to row 2
# For cell 27, adding cell dof 104 to number 3
# For cell 27, adding cell dof 105 to number 4
# For cell 28, adding vertex dof 28 to row 1
# For cell 28, adding vertex dof 29 to row 2
# For cell 28, adding cell dof 106 to number 3
# For cell 28, adding cell dof 107 to number 4
# For cell 29, adding vertex dof 29 to row 1
# For cell 29, adding vertex dof 30 to row 2
# For cell 29, adding cell dof 108 to number 3
# For cell 29, adding cell dof 109 to number 4
# For cell 30, adding vertex dof 30 to row 1
# For cell 30, adding vertex dof 31 to row 2
# For cell 30, adding cell dof 110 to number 3
# For cell 30, adding cell dof 111 to number 4
# For cell 31, adding vertex dof 31 to row 1
# For cell 31, adding vertex dof 32 to row 2
# For cell 31, adding cell dof 112 to number 3
# For cell 31, adding cell dof 113 to number 4
# For cell 32, adding vertex dof 32 to row 1
# For cell 32, adding vertex dof 33 to row 2
# For cell 32, adding cell dof 114 to number 3
# For cell 32, adding cell dof 115 to number 4
# For cell 33, adding vertex dof 33 to row 1
# For cell 33, adding vertex dof 34 to row 2
# For cell 33, adding cell dof 116 to number 3
# For cell 33, adding cell dof 117 to number 4
# For cell 34, adding vertex dof 34 to row 1
# For cell 34, adding vertex dof 35 to row 2
# For cell 34, adding cell dof 118 to number 3
# For cell 34, adding cell dof 119 to number 4
# For cell 35, adding vertex dof 35 to row 1
# For cell 35, adding vertex dof 36 to row 2
# For cell 35, adding cell dof 120 to number 3
# For cell 35, adding cell dof 121 to number 4
# For cell 36, adding vertex dof 36 to row 1
# For cell 36, adding vertex dof 37 to row 2
# For cell 36, adding cell dof 122 to number 3
# For cell 36, adding cell dof 123 to number 4
# For cell 37, adding vertex dof 37 to row 1
# For cell 37, adding vertex dof 38 to row 2
# For cell 37, adding cell dof 124 to number 3
# For cell 37, adding cell dof 125 to number 4
# For cell 38, adding vertex dof 38 to row 1
# For cell 38, adding vertex dof 39 to row 2
# For cell 38, adding cell dof 126 to number 3
# For cell 38, adding cell dof 127 to number 4
# For cell 39, adding vertex dof 39 to row 1
# For cell 39, adding vertex dof 40 to row 2
# For cell 39, adding cell dof 128 to number 3
# For cell 39, adding cell dof 129 to number 4
# For cell 40, adding vertex dof 40 to row 1
# For cell 40, adding vertex dof 41 to row 2
# For cell 40, adding cell dof 130 to number 3
# For cell 40, adding cell dof 131 to number 4
# For cell 41, adding vertex dof 41 to row 1
# For cell 41, adding vertex dof 42 to row 2
# For cell 41, adding cell dof 132 to number 3
# For cell 41, adding cell dof 133 to number 4
# For cell 42, adding vertex dof 42 to row 1
# For cell 42, adding vertex dof 43 to row 2
# For cell 42, adding cell dof 134 to number 3
# For cell 42, adding cell dof 135 to number 4
# For cell 43, adding vertex dof 43 to row 1
# For cell 43, adding vertex dof 44 to row 2
# For cell 43, adding cell dof 136 to number 3
# For cell 43, adding cell dof 137 to number 4
# For cell 44, adding vertex dof 44 to row 1
# For cell 44, adding vertex dof 45 to row 2
# For cell 44, adding cell dof 138 to number 3
# For cell 44, adding cell dof 139 to number 4
# For cell 45, adding vertex dof 45 to row 1
# For cell 45, adding vertex dof 46 to row 2
# For cell 45, adding cell dof 140 to number 3
# For cell 45, adding cell dof 141 to number 4
# For cell 46, adding vertex dof 46 to row 1
# For cell 46, adding vertex dof 47 to row 2
# For cell 46, adding cell dof 142 to number 3
# For cell 46, adding cell dof 143 to number 4
# For cell 47, adding vertex dof 47 to row 1
# For cell 47, adding vertex dof 48 to row 2
# For cell 47, adding cell dof 144 to number 3
# For cell 47, adding cell dof 145 to number 4
# For cell 48, adding vertex dof 48 to row 1
# For cell 48, adding vertex dof 49 to row 2
# For cell 48, adding cell dof 146 to number 3
# For cell 48, adding cell dof 147 to number 4
# For cell 49, adding vertex dof 49 to row 1
# For cell 49, adding vertex dof 50 to row 2
# For cell 49, adding cell dof 148 to number 3
# For cell 49, adding cell dof 149 to number 4
# For cell 50, adding vertex dof 50 to row 1
# For cell 50, adding vertex dof 51 to row 2
# For cell 50, adding cell dof 150 to number 3
# For cell 50, adding cell dof 151 to number 4
# true

# %%
dbcs = DirichletBoundaryConditions(dh)
add!(dbcs, :T, getfaceset(grid, "left"), (x,t) -> 0, [1])
add!(dbcs, :T, getfaceset(grid, "right"), (x,t) -> 0, [1])
close!(dbcs)
update!(dbcs, 0.0)
# Out:
# n_geom_basefuncs = 2
# n_geom_basefuncs = 2

# %%
K = create_sparsity_pattern(dh);
fill!(K.nzval, 1.0);
spy(K)
# Out:
#                     Sparsity Pattern
#        ┌──────────────────────────────────────────┐
#      1 │⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⠶⢤⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│ > 0
#        │⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠙⠷⣤⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│ < 0
#        │⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠙⠲⣦⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#        │⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠙⠲⢤⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#        │⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠛⠲⢤⣀⠀⠀⠀⠀⠀⠀⠀⠀│
#        │⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠛⠶⣤⣀⠀⠀⠀⠀│
#        │⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠙⠲⣦⣀│
#        │⢻⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉│
#        │⠀⢳⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#        │⠀⠀⢷⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#        │⠀⠀⠀⢻⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠛⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#        │⠀⠀⠀⠀⢳⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#        │⠀⠀⠀⠀⠈⢻⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#        │⠀⠀⠀⠀⠀⠀⢳⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#        │⠀⠀⠀⠀⠀⠀⠀⢷⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠱⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#        │⠀⠀⠀⠀⠀⠀⠀⠀⢻⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⢆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#        │⠀⠀⠀⠀⠀⠀⠀⠀⠀⢳⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀│
#        │⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢻⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠻⣦⡀⠀⠀⠀⠀⠀│
#        │⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢻⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠛⢄⠀⠀⠀⠀│
#        │⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢳⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⣤⡀⠀│
#    151 │⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢻⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦│
#        └──────────────────────────────────────────┘
#        1                                        151
#                         nz = 751

# %%
function doassemble{dim}(cellvalues::CellScalarValues{dim}, K::SparseMatrixCSC, dh::DofHandler)
    b = 1.0
    f = zeros(ndofs(dh))
    assembler = start_assemble(K, f)
    
    n_basefuncs = getnbasefunctions(cellvalues)
    global_dofs = zeros(Int, ndofs_per_cell(dh))

    fe = zeros(n_basefuncs) # Local force vector
    Ke = zeros(n_basefuncs, n_basefuncs) # Local stiffness mastrix

    @inbounds for (cellcount, cell) in enumerate(CellIterator(dh))
        fill!(Ke, 0)
        fill!(fe, 0)
        
        reinit!(cellvalues, cell)
        for q_point in 1:getnquadpoints(cellvalues)
            dΩ = getdetJdV(cellvalues, q_point)
            for i in 1:n_basefuncs
                δT = shape_value(cellvalues, q_point, i)
                ∇δT = shape_gradient(cellvalues, q_point, i)
                fe[i] += (δT * b) * dΩ
                for j in 1:n_basefuncs
                    ∇T = shape_gradient(cellvalues, q_point, j)
                    Ke[i, j] += (∇δT ⋅ ∇T) * dΩ
                end
            end
        end
        
        celldofs!(global_dofs, cell)
        assemble!(assembler, global_dofs, fe, Ke)
    end
    return K, f
end
# Out:
# WARNING: Method definition doassemble(JuAFEM.CellScalarValues{#dim<:Any, T<:Real, refshape<:JuAFEM.AbstractRefShape}, Base.SparseArrays.SparseMatrixCSC, JuAFEM.DofHandler) in module Main at In[79]:2 overwritten at In[91]:2.
# doassemble (generic function with 1 method)

# %%
K, f = doassemble(cellvalues, K, dh);

# %%
apply!(K, f, dbcs)
T = K \ f;

# %%
T_vertices = T[unique(dh.dof_storage[1].cell_vertex_dofs[:])];

# %%
plot(T_vertices)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="407.295pt" height="262.959pt" viewBox="0 0 407.295 262.959" version="1.1">
# <defs>
# <g>
# <symbol overflow="visible" id="glyph-1491726440446187-0-0">
# <path style="stroke:none;" d=""/>
# </symbol>
# <symbol overflow="visible" id="glyph-1491726440446187-0-1">
# <path style="stroke:none;" d="M 4.46875 -2 C 4.46875 -3.1875 3.65625 -4.1875 2.578125 -4.1875 C 2.109375 -4.1875 1.671875 -4.03125 1.3125 -3.671875 L 1.3125 -5.625 C 1.515625 -5.5625 1.84375 -5.5 2.15625 -5.5 C 3.390625 -5.5 4.09375 -6.40625 4.09375 -6.53125 C 4.09375 -6.59375 4.0625 -6.640625 3.984375 -6.640625 C 3.