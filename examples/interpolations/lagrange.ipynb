# %%
using JuAFEM
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
JuAFEM.degreesoffreedom(Lagrange{1, RefCube, 1}(), size = (300,300))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="300" height="300" viewBox="0 0 300 300">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="300" height="300"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,300 300,300 300,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="60" y="30" width="211" height="211"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.4926,284.952 296.063,284.952 296.063,3.93701 39.4926,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="3" width="257" height="282"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.6; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.4926,280.737 39.4926,8.15223
#   "/>
# ...

# %%
JuAFEM.degreesoffreedom(Lagrange{1, RefCube, 5}(), size = (300,300))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="300" height="300" viewBox="0 0 300 300">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="300" height="300"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,300 300,300 300,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="60" y="30" width="211" height="211"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.4926,284.952 296.063,284.952 296.063,3.93701 39.4926,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="3" width="257" height="282"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.6; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.4926,280.737 39.4926,8.15223
#   "/>
# ...

# %%
ip = Lagrange{1, RefCube, 4}()
p = plot(legend = true)
for i in 1:JuAFEM.getnbasefunctions(ip)
    JuAFEM.shapefunction!(ip, i, label ="Shape function $i")
end
p
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 30.6037,384.952 596.063,384.952 596.063,3.93701 30.6037,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="30" y="3" width="566" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   30.6037,379.237 30.6037,9.65223
#   "/>
# ...

# %%
ip = Lagrange{2, RefCube, 1}()
JuAFEM.shapefunction(ip, 2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.4926,384.952 596.063,384.952 596.063,3.93701 39.4926,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="3" width="497" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,279.187 266.056,128.972
#   "/>
# ...

# %%
ip = Lagrange{2, RefCube, 2}()
JuAFEM.shapefunction(ip, 9)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.4926,384.952 596.063,384.952 596.063,3.93701 39.4926,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="3" width="497" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,258.348 266.056,108.133
#   "/>
# ...

# %%
ip = Lagrange{2, RefCube, 3}()
JuAFEM.shapefunction(ip, 1)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.4926,384.952 596.063,384.952 596.063,3.93701 39.4926,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="3" width="497" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,279.187 266.056,128.972
#   "/>
# ...
