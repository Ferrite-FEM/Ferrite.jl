# %%
using JuAFEM
using Plots
pgfplots()
# Out:
# Plots.PGFPlotsBackend()

# %%
plot(Lagrange{1, RefCube, 1}(), size = (300,300))
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="198.684pt" height="191.788pt" viewBox="0 0 198.684 191.788" version="1.1">
# <defs>
# <g>
# <symbol overflow="visible" id="glyph-1491726440446194-0-0">
# <path style="stroke:none;" d=""/>
# </symbol>
# <symbol overflow="visible" id="glyph-1491726440446194-0-1">
# <path style="stroke:none;" d="M 6.5625 -2.296875 C 6.734375 -2.296875 6.921875 -2.296875 6.921875 -2.5 C 6.921875 -2.6875 6.734375 -2.6875 6.5625 -2.6875 L 1.171875 -2.6875 C 1 -2.6875 0.828125 -2.6875 0.828125 -2.5 C 0.828125 -2.296875 1 -2.296875 1.171875 -2.296875 Z M 6.5625 -2.296875 "/>
# </symbol>
# <symbol overflow="visible" id="glyph-1491726440446194-1-0">
# <path style="stroke:none;" d=""/>
# </symbol>
# <symbol overflow="visible" id="glyph-1491726440446194-1-1">
# ...

# %%
plot(Lagrange{1, RefCube, 5}(), size = (300,300))
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="198.684pt" height="191.788pt" viewBox="0 0 198.684 191.788" version="1.1">
# <defs>
# <g>
# <symbol overflow="visible" id="glyph-1491726440446195-0-0">
# <path style="stroke:none;" d=""/>
# </symbol>
# <symbol overflow="visible" id="glyph-1491726440446195-0-1">
# <path style="stroke:none;" d="M 6.5625 -2.296875 C 6.734375 -2.296875 6.921875 -2.296875 6.921875 -2.5 C 6.921875 -2.6875 6.734375 -2.6875 6.5625 -2.6875 L 1.171875 -2.6875 C 1 -2.6875 0.828125 -2.6875 0.828125 -2.5 C 0.828125 -2.296875 1 -2.296875 1.171875 -2.296875 Z M 6.5625 -2.296875 "/>
# </symbol>
# <symbol overflow="visible" id="glyph-1491726440446195-1-0">
# <path style="stroke:none;" d=""/>
# </symbol>
# <symbol overflow="visible" id="glyph-1491726440446195-1-1">
# ...
